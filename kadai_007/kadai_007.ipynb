# %% [markdown]
# <a href="https://colab.research.google.com/github/hourglassfigure-smartman/Python-basic-kadai/blob/main/kadai_007.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# リスト（array）を作成
array_lists = ["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです", "木曜日は晴れです", "金曜日は曇りです", "土曜日は曇りのち雨です", "日曜日は雷雨です"]

# ディクショナリ（dictionary）を作成
dictionary = {"mon": "晴れ", "tue": "雨", "wed": "晴れ", "thu": "晴れ", "fri": "曇り", "sat": "曇りのち雨", "sun": "雷雨"}

# 水曜日の天気予報を取り出して出力
print(array_lists[2])
print(dictionary["wed"])
# Out:
# 水曜日は晴れです
# 晴れ
