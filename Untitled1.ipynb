# %% [markdown]
# <a href="https://colab.research.google.com/github/hourglassfigure-smartman/Python-basic-kadai/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user_names = ["侍太郎", "侍一郎", "侍二郎", "侍三郎", "侍四郎"]

print(user_names[1]) # 2番目の要素だけを表示

user_names[1] = "侍花子" # 2番目の要素を更新
print(user_names)

user_names.append("侍五郎") # 6番目の要素を追加
print(user_names)

user_names.pop(2) # 3番目の要素を削除（0始まりのため2を指定）
print(user_names)
# Out:
# 侍一郎
# ['侍太郎', '侍花子', '侍二郎', '侍三郎', '侍四郎']
# ['侍太郎', '侍花子', '侍二郎', '侍三郎', '侍四郎', '侍五郎']
# ['侍太郎', '侍花子', '侍三郎', '侍四郎', '侍五郎']

# %%
country_names = ("日本", "アメリカ", "イギリス", "フランス" )

# 3番目の要素を取り出す
print(country_names[2])

# すべての要素を取り出す
print(country_names)
# Out:
# イギリス
# ('日本', 'アメリカ', 'イギリス', 'フランス')

# %%
country_names = {"アメリカ", "イギリス", "日本", "フランス"}

# セット全体を表示
print(country_names)
# Out:
# {'アメリカ', 'イギリス', 'フランス', '日本'}

# %%
# 1～10までに含まれる素数のセット（2と5が重複）
prime_numbers = {2, 5, 2, 7, 3, 5, 5 }

# セット全体を表示
print(prime_numbers)
# Out:
# {2, 3, 5, 7}

# %%
stationery_prices = {"鉛筆": 70, "ボールペン": 120, "シャープペンシル": 150, "消しゴム": 90}

# 「シャープペンシル」を要素ごと削除
stationery_prices.pop("シャープペンシル")

# 連想配列全体を取り出して表示
print(stationery_prices)
# Out:
# {'鉛筆': 70, 'ボールペン': 120, '消しゴム': 90}

# %%
# 連想配列を作成
personal_data = {"name": "侍太郎", "age": 36, "gender": "男性"}

# キー「name」の値を表示
print(personal_data["name"])

# 連想配列全体を表示
print(personal_data)

# キー「age」の値を更新
personal_data["age"] = 37

# 新しく要素（キーと値）を追加
personal_data["address"] = "東京都"

# 連想配列全体を表示
print(personal_data)

# %%
# リスト（array）を作成
array_lists = ["月曜日は晴れです", "火曜日は雨です", "水曜日は晴れです", "木曜日は晴れです", "金曜日は曇りです", "土曜日は曇りのち雨です", "日曜日は雷雨です"]

# ディクショナリ（dictionary）を作成
dictionary = {"mon": "晴れ", "tue": "雨", "wed": "晴れ", "thu": "晴れ", "fri": "曇り", "sat": "曇りのち雨", "sun": "雷雨"}

# 水曜日の天気予報を取り出して出力
print(array_lists[2])
print(dictionary["wed"])
# Out:
# 水曜日は晴れです
# 晴れ
